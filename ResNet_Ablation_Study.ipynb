# %% [markdown]
# <a href="https://colab.research.google.com/github/tmsk0711/GoingDeeper/blob/main/%08ResNet_Ablation_Study.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras

import numpy as np
import matplotlib.pyplot as plt
import tensorflow_datasets as tfds

print(tf.__version__)
print(np.__version__)
# Out:
# 2.8.0
# 1.21.5

# %%
import urllib3
urllib3.disable_warnings()

#tfds.disable_progress_bar()   # 이 주석을 풀면 데이터셋 다운로드과정의 프로그레스바가 나타나지 않습니다.

(ds_train, ds_test), ds_info = tfds.load(
    'cifar10',
    split=['train', 'test'],
    shuffle_files=True,
    with_info=True,
)
# Out:
# Downloading and preparing dataset cifar10/3.0.2 (download: 162.17 MiB, generated: 132.40 MiB, total: 294.58 MiB) to /root/tensorflow_datasets/cifar10/3.0.2...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# 0 examples [00:00, ? examples/s]
# Shuffling and writing examples to /root/tensorflow_datasets/cifar10/3.0.2.incomplete64725D/cifar10-train.tfrecord
#   0%|          | 0/50000 [00:00<?, ? examples/s]
# 0 examples [00:00, ? examples/s]
# Shuffling and writing examples to /root/tensorflow_datasets/cifar10/3.0.2.incomplete64725D/cifar10-test.tfrecord
#   0%|          | 0/10000 [00:00<?, ? examples/s]
# Dataset cifar10 downloaded and prepared to /root/tensorflow_datasets/cifar10/3.0.2. Subsequent calls will reuse this data.

# %%
# 데이터의 개수도 확인해 봅시다. 
print(tf.data.experimental.cardinality(ds_train))
print(tf.data.experimental.cardinality(ds_test))
# Out:
# tf.Tensor(50000, shape=(), dtype=int64)
# tf.Tensor(10000, shape=(), dtype=int64)

# %%
# is_50 : True --> resnet_50
# is_plain :True --> no skip connection    
def build_resnet_block(input_layer, num_cnn=3, channel=64, block_num=1,is_50 = False,is_plain = False):
    # 입력 레이어
    x = input_layer
    if not is_50:
    # CNN 레이어
        for cnn_num in range(num_cnn):
            identity = x
            x = keras.layers.Conv2D(
                filters=channel,
                kernel_size=(3,3),
                activation='relu',
                kernel_initializer='he_normal',
                padding='same',
                name=f'block{block_num}_conv{cnn_num}'
            )(x)
            x = keras.layers.BatchNormalization()(x)
            x = keras.layers.Conv2D(
                filters=channel,
                kernel_size=(3,3),
                activation='relu',
                kernel_initializer='he_normal',
                padding='same',
                name=f'block{block_num}_1_conv{cnn_num}'
            )(x)
            if not is_plain:
                identity_channel = identity.shape.as_list()[-1]    

                if identity_channel != channel:
                    identity = keras.layers.Conv2D(channel, kernel_size=(1, 1), strides=(1, 1), padding="same")(identity)  
                # skip connection
                x = keras.layers.Add()([x,identity])   
            else:
                pass
    else :
        identity = x
        x = keras.layers.Conv2D(
            filters=channel,
            kernel_size=(1,1),
            activation='relu',
            kernel_initializer='he_normal',
            padding='same',
            name=f'block{block_num}_conv{cnn_num}'
        )(x)
        x = keras.layers.BatchNormalization()(x)
        x = keras.layers.Conv2D(
            filters=channel,
            kernel_size=(3,3),
            activation='relu',
            kernel_initializer='he_normal',
            padding='same',
            name=f'block{block_num}_1_conv{cnn_num}'
        )(x)
        x = keras.layers.Conv2D(
            filters=channel * 4,
            kernel_size=(1,1),
            activation='relu',
            kernel_initializer='he_normal',
            padding='same',
            name=f'block{block_num}_2_conv{cnn_num}'
        )(x)
        if not is_plain:
            identity_channel = identity.shape.as_list()[-1]    

            if identity_channel != channel:
                identity = keras.layers.Conv2D(channel, kernel_size=(1, 1), strides=(1, 1), padding="same")(identity)  
            # skip connection
            x = keras.layers.Add()([x,identity])   
        else:
            pass
    #     Max Pooling 레이어
    # 마지막 블록 뒤에는 pooling을 하지 않음
    if identity.shape[1] != 1:        
        x = keras.layers.MaxPooling2D(
            pool_size=(2, 2),
            strides=2,
            name=f'block{block_num}_pooling'
        )(x)

    return x

# %%
def build_resnet(input_shape=(32,32,3),
              num_cnn_list=[3,4,6,3],
              channel_list=[64,128,256,512],
              num_classes=10,is_50 = False, is_plain = False):
    
    assert len(num_cnn_list) == len(channel_list) #모델을 만들기 전에 config list들이 같은 길이인지 확인합니다.
    if is_50:
        num_cnn_list = [3,4,6,3]
        channel_list = [64,128,256,512]
        num_classes = 10
        
    input_layer = keras.layers.Input(shape=input_shape)  # input layer를 만들어둡니다.
    output = input_layer
    #conv1층
    output = keras.layers.Conv2D(filters=64,
                       kernel_size = (2,2),
                       strides = 2,
                         padding = 'valid')(output)
    output = keras.layers.BatchNormalization()(output)
    
    #conv2_x pooling
    output = keras.layers.MaxPooling2D(pool_size = (2,2),
                                      strides = 2,)(output)    
    # config list들의 길이만큼 반복해서 블록을 생성합니다.
    for i, (num_cnn, channel) in enumerate(zip(num_cnn_list, channel_list)):
        output = build_resnet_block(
            output,
            num_cnn=num_cnn, 
            channel=channel,
            block_num=i
        )    
    output = keras.layers.AveragePooling2D(padding = 'same')(output)
    output = keras.layers.Flatten(name='flatten')(output)
    output = keras.layers.Dense(512, activation='relu', name='fc1')(output)    
    output = keras.layers.Dense(num_classes, activation='softmax', name='predictions')(output)
    
    model = keras.Model(
        inputs=input_layer, 
        outputs=output
    )
    return model

# %%
resnet_34 = build_resnet(is_50=False)
resnet_50 = build_resnet(is_50=True)
resnet_34.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  conv2d (Conv2D)                (None, 16, 16, 64)   832         ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 16, 16, 64)  256         ['conv2d[0][0]']
#  alization)
#
#  max_pooling2d (MaxPooling2D)   (None, 8, 8, 64)     0           ['batch_normalization[0][0]']
#
#  block0_conv0 (Conv2D)          (None, 8, 8, 64)     36928       ['max_pooling2d[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 8, 8, 64)    256         ['block0_conv0[0][0]']
#  rmalization)
#
#  block0_1_conv0 (Conv2D)        (None, 8, 8, 64)     36928       ['batch_normalization_1[0][0]']
#
#  add (Add)                      (None, 8, 8, 64)     0           ['block0_1_conv0[0][0]',
#                                                                   'max_pooling2d[0][0]']
#
#  block0_conv1 (Conv2D)          (None, 8, 8, 64)     36928       ['add[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 8, 8, 64)    256         ['block0_conv1[0][0]']
#  rmalization)
#
#  block0_1_conv1 (Conv2D)        (None, 8, 8, 64)     36928       ['batch_normalization_2[0][0]']
#
#  add_1 (Add)                    (None, 8, 8, 64)     0           ['block0_1_conv1[0][0]',
#                                                                   'add[0][0]']
#
#  block0_conv2 (Conv2D)          (None, 8, 8, 64)     36928       ['add_1[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 8, 8, 64)    256         ['block0_conv2[0][0]']
#  rmalization)
#
#  block0_1_conv2 (Conv2D)        (None, 8, 8, 64)     36928       ['batch_normalization_3[0][0]']
#
#  add_2 (Add)                    (None, 8, 8, 64)     0           ['block0_1_conv2[0][0]',
#                                                                   'add_1[0][0]']
#
#  block0_pooling (MaxPooling2D)  (None, 4, 4, 64)     0           ['add_2[0][0]']
#
#  block1_conv0 (Conv2D)          (None, 4, 4, 128)    73856       ['block0_pooling[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 4, 4, 128)   512         ['block1_conv0[0][0]']
#  rmalization)
#
#  block1_1_conv0 (Conv2D)        (None, 4, 4, 128)    147584      ['batch_normalization_4[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 4, 4, 128)    8320        ['block0_pooling[0][0]']
#
#  add_3 (Add)                    (None, 4, 4, 128)    0           ['block1_1_conv0[0][0]',
#                                                                   'conv2d_1[0][0]']
#
#  block1_conv1 (Conv2D)          (None, 4, 4, 128)    147584      ['add_3[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 4, 4, 128)   512         ['block1_conv1[0][0]']
#  rmalization)
#
#  block1_1_conv1 (Conv2D)        (None, 4, 4, 128)    147584      ['batch_normalization_5[0][0]']
#
#  add_4 (Add)                    (None, 4, 4, 128)    0           ['block1_1_conv1[0][0]',
#                                                                   'add_3[0][0]']
#
#  block1_conv2 (Conv2D)          (None, 4, 4, 128)    147584      ['add_4[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 4, 4, 128)   512         ['block1_conv2[0][0]']
#  rmalization)
#
#  block1_1_conv2 (Conv2D)        (None, 4, 4, 128)    147584      ['batch_normalization_6[0][0]']
#
#  add_5 (Add)                    (None, 4, 4, 128)    0           ['block1_1_conv2[0][0]',
#                                                                   'add_4[0][0]']
#
#  block1_conv3 (Conv2D)          (None, 4, 4, 128)    147584      ['add_5[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 4, 4, 128)   512         ['block1_conv3[0][0]']
#  rmalization)
#
#  block1_1_conv3 (Conv2D)        (None, 4, 4, 128)    147584      ['batch_normalization_7[0][0]']
#
#  add_6 (Add)                    (None, 4, 4, 128)    0           ['block1_1_conv3[0][0]',
#                                                                   'add_5[0][0]']
#
#  block1_pooling (MaxPooling2D)  (None, 2, 2, 128)    0           ['add_6[0][0]']
#
#  block2_conv0 (Conv2D)          (None, 2, 2, 256)    295168      ['block1_pooling[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 2, 2, 256)   1024        ['block2_conv0[0][0]']
#  rmalization)
#
#  block2_1_conv0 (Conv2D)        (None, 2, 2, 256)    590080      ['batch_normalization_8[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 2, 2, 256)    33024       ['block1_pooling[0][0]']
#
#  add_7 (Add)                    (None, 2, 2, 256)    0           ['block2_1_conv0[0][0]',
#                                                                   'conv2d_2[0][0]']
#
#  block2_conv1 (Conv2D)          (None, 2, 2, 256)    590080      ['add_7[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 2, 2, 256)   1024        ['block2_conv1[0][0]']
#  rmalization)
#
#  block2_1_conv1 (Conv2D)        (None, 2, 2, 256)    590080      ['batch_normalization_9[0][0]']
#
#  add_8 (Add)                    (None, 2, 2, 256)    0           ['block2_1_conv1[0][0]',
#                                                                   'add_7[0][0]']
#
#  block2_conv2 (Conv2D)          (None, 2, 2, 256)    590080      ['add_8[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 2, 2, 256)   1024        ['block2_conv2[0][0]']
#  ormalization)
#
#  block2_1_conv2 (Conv2D)        (None, 2, 2, 256)    590080      ['batch_normalization_10[0][0]']
#
#  add_9 (Add)                    (None, 2, 2, 256)    0           ['block2_1_conv2[0][0]',
#                                                                   'add_8[0][0]']
#
#  block2_conv3 (Conv2D)          (None, 2, 2, 256)    590080      ['add_9[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 2, 2, 256)   1024        ['block2_conv3[0][0]']
#  ormalization)
#
#  block2_1_conv3 (Conv2D)        (None, 2, 2, 256)    590080      ['batch_normalization_11[0][0]']
#
#  add_10 (Add)                   (None, 2, 2, 256)    0           ['block2_1_conv3[0][0]',
#                                                                   'add_9[0][0]']
#
#  block2_conv4 (Conv2D)          (None, 2, 2, 256)    590080      ['add_10[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 2, 2, 256)   1024        ['block2_conv4[0][0]']
#  ormalization)
#
#  block2_1_conv4 (Conv2D)        (None, 2, 2, 256)    590080      ['batch_normalization_12[0][0]']
#
#  add_11 (Add)                   (None, 2, 2, 256)    0           ['block2_1_conv4[0][0]',
#                                                                   'add_10[0][0]']
#
#  block2_conv5 (Conv2D)          (None, 2, 2, 256)    590080      ['add_11[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 2, 2, 256)   1024        ['block2_conv5[0][0]']
#  ormalization)
#
#  block2_1_conv5 (Conv2D)        (None, 2, 2, 256)    590080      ['batch_normalization_13[0][0]']
#
#  add_12 (Add)                   (None, 2, 2, 256)    0           ['block2_1_conv5[0][0]',
#                                                                   'add_11[0][0]']
#
#  block2_pooling (MaxPooling2D)  (None, 1, 1, 256)    0           ['add_12[0][0]']
#
#  block3_conv0 (Conv2D)          (None, 1, 1, 512)    1180160     ['block2_pooling[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 1, 1, 512)   2048        ['block3_conv0[0][0]']
#  ormalization)
#
#  block3_1_conv0 (Conv2D)        (None, 1, 1, 512)    2359808     ['batch_normalization_14[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 1, 1, 512)    131584      ['block2_pooling[0][0]']
#
#  add_13 (Add)                   (None, 1, 1, 512)    0           ['block3_1_conv0[0][0]',
#                                                                   'conv2d_3[0][0]']
#
#  block3_conv1 (Conv2D)          (None, 1, 1, 512)    2359808     ['add_13[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 1, 1, 512)   2048        ['block3_conv1[0][0]']
#  ormalization)
#
#  block3_1_conv1 (Conv2D)        (None, 1, 1, 512)    2359808     ['batch_normalization_15[0][0]']
#
#  add_14 (Add)                   (None, 1, 1, 512)    0           ['block3_1_conv1[0][0]',
#                                                                   'add_13[0][0]']
#
#  block3_conv2 (Conv2D)          (None, 1, 1, 512)    2359808     ['add_14[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 1, 1, 512)   2048        ['block3_conv2[0][0]']
#  ormalization)
#
#  block3_1_conv2 (Conv2D)        (None, 1, 1, 512)    2359808     ['batch_normalization_16[0][0]']
#
#  add_15 (Add)                   (None, 1, 1, 512)    0           ['block3_1_conv2[0][0]',
#                                                                   'add_14[0][0]']
#
#  average_pooling2d (AveragePool  (None, 1, 1, 512)   0           ['add_15[0][0]']
#  ing2D)
#
#  flatten (Flatten)              (None, 512)          0           ['average_pooling2d[0][0]']
#
#  fc1 (Dense)                    (None, 512)          262656      ['flatten[0][0]']
#
#  predictions (Dense)            (None, 10)           5130        ['fc1[0][0]']
#
# ==================================================================================================
# Total params: 21,550,666
# Trainable params: 21,542,986
# Non-trainable params: 7,680
# __________________________________________________________________________________________________

# %%
def normalize_and_resize_img(image, label):
    """Normalizes images: `uint8` -> `float32`."""
    # image = tf.image.resize(image, [32, 32])
    return tf.cast(image, tf.float32) / 255., label

def apply_normalize_on_dataset(ds, is_test=False, batch_size=16):
    ds = ds.map(
        normalize_and_resize_img, 
        num_parallel_calls=1
    )
    ds = ds.batch(batch_size)
    if not is_test:
        ds = ds.repeat()
        ds = ds.shuffle(200)
    ds = ds.prefetch(tf.data.experimental.AUTOTUNE)
    return ds

# %%
BATCH_SIZE = 256
EPOCH = 15
(ds_train, ds_test), ds_info = tfds.load(
    'cifar10',
    split=['train', 'test'],
    as_supervised=True,
    shuffle_files=True,
    with_info=True,
)
ds_train = apply_normalize_on_dataset(ds_train, batch_size=BATCH_SIZE)
ds_test = apply_normalize_on_dataset(ds_test, batch_size=BATCH_SIZE)

# %%
resnet_34.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=tf.keras.optimizers.SGD(lr=0.01, clipnorm=1.),
    metrics=['accuracy'],
)

histoty_34 = resnet_34.fit(
    ds_train,
    steps_per_epoch=int(ds_info.splits['train'].num_examples/BATCH_SIZE),
    validation_steps=int(ds_info.splits['test'].num_examples/BATCH_SIZE),
    epochs=EPOCH,
    validation_data=ds_test,
    verbose=1,
    use_multiprocessing=True,
)
# Out:
# Epoch 1/15
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# 195/195 [==============================] - 35s 79ms/step - loss: 2.1185 - accuracy: 0.3136 - val_loss: 3.4705 - val_accuracy: 0.1052
# Epoch 2/15
# 195/195 [==============================] - 13s 67ms/step - loss: 1.5762 - accuracy: 0.4376 - val_loss: 2.5227 - val_accuracy: 0.2349
# Epoch 3/15
# 195/195 [==============================] - 13s 66ms/step - loss: 1.3843 - accuracy: 0.5069 - val_loss: 1.7252 - val_accuracy: 0.3932
# Epoch 4/15
# 195/195 [==============================] - 13s 66ms/step - loss: 1.2622 - accuracy: 0.5470 - val_loss: 1.5106 - val_accuracy: 0.4784
# Epoch 5/15
# 195/195 [==============================] - 13s 68ms/step - loss: 1.1416 - accuracy: 0.5925 - val_loss: 1.4577 - val_accuracy: 0.4849
# Epoch 6/15
# 195/195 [==============================] - 13s 66ms/step - loss: 1.0292 - accuracy: 0.6358 - val_loss: 1.3986 - val_accuracy: 0.5113
# Epoch 7/15
# 195/195 [==============================] - 13s 67ms/step - loss: 0.9350 - accuracy: 0.6694 - val_loss: 1.3643 - val_accuracy: 0.5312
# Epoch 8/15
# 195/195 [==============================] - 13s 67ms/step - loss: 0.8334 - accuracy: 0.7086 - val_loss: 1.4371 - val_accuracy: 0.5244
# Epoch 9/15
# 195/195 [==============================] - 13s 67ms/step - loss: 0.7297 - accuracy: 0.7482 - val_loss: 1.4340 - val_accuracy: 0.5331
# Epoch 10/15
# 195/195 [==============================] - 15s 78ms/step - loss: 0.6327 - accuracy: 0.7864 - val_loss: 1.4319 - val_accuracy: 0.5462
# Epoch 11/15
# 195/195 [==============================] - 13s 67ms/step - loss: 0.5268 - accuracy: 0.8281 - val_loss: 1.4994 - val_accuracy: 0.5319
# Epoch 12/15
# 195/195 [==============================] - 13s 67ms/step - loss: 0.4313 - accuracy: 0.8632 - val_loss: 1.5771 - val_accuracy: 0.5371
# Epoch 13/15
# 195/195 [==============================] - 13s 67ms/step - loss: 0.3488 - accuracy: 0.8920 - val_loss: 1.6989 - val_accuracy: 0.5300
# Epoch 14/15
# 195/195 [==============================] - 13s 67ms/step - loss: 0.2607 - accuracy: 0.9253 - val_loss: 1.7758 - val_accuracy: 0.5303
# Epoch 15/15
# 195/195 [==============================] - 13s 67ms/step - loss: 0.1917 - accuracy: 0.9497 - val_loss: 2.0034 - val_accuracy: 0.5291

# %%
resnet_50.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=tf.keras.optimizers.SGD(lr=0.01, clipnorm=1.),
    metrics=['accuracy'],
)

histoty_50 = resnet_50.fit(
    ds_train,
    steps_per_epoch=int(ds_info.splits['train'].num_examples/BATCH_SIZE),
    validation_steps=int(ds_info.splits['test'].num_examples/BATCH_SIZE),
    epochs=EPOCH,
    validation_data=ds_test,
    verbose=1,
    use_multiprocessing=True,
)
# Out:
# Epoch 1/15
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# 195/195 [==============================] - 20s 70ms/step - loss: 2.0056 - accuracy: 0.3216 - val_loss: 2.8989 - val_accuracy: 0.1500
# Epoch 2/15
# 195/195 [==============================] - 15s 76ms/step - loss: 1.5532 - accuracy: 0.4509 - val_loss: 2.4129 - val_accuracy: 0.2340
# Epoch 3/15
# 195/195 [==============================] - 13s 67ms/step - loss: 1.3723 - accuracy: 0.5123 - val_loss: 1.6665 - val_accuracy: 0.4072
# Epoch 4/15
# 195/195 [==============================] - 13s 67ms/step - loss: 1.2526 - accuracy: 0.5527 - val_loss: 1.4902 - val_accuracy: 0.4718
# Epoch 5/15
# 195/195 [==============================] - 13s 66ms/step - loss: 1.1335 - accuracy: 0.5990 - val_loss: 1.3790 - val_accuracy: 0.5272
# Epoch 6/15
# 195/195 [==============================] - 13s 66ms/step - loss: 1.0221 - accuracy: 0.6390 - val_loss: 1.4174 - val_accuracy: 0.5088
# Epoch 7/15
# 195/195 [==============================] - 13s 66ms/step - loss: 0.9200 - accuracy: 0.6782 - val_loss: 1.3965 - val_accuracy: 0.5246
# Epoch 8/15
# 195/195 [==============================] - 13s 66ms/step - loss: 0.8132 - accuracy: 0.7151 - val_loss: 1.4342 - val_accuracy: 0.5151
# Epoch 9/15
# 195/195 [==============================] - 15s 77ms/step - loss: 0.7106 - accuracy: 0.7559 - val_loss: 1.5002 - val_accuracy: 0.5200
# Epoch 10/15
# 195/195 [==============================] - 13s 66ms/step - loss: 0.6141 - accuracy: 0.7932 - val_loss: 1.4712 - val_accuracy: 0.5367
# Epoch 11/15
# 195/195 [==============================] - 13s 67ms/step - loss: 0.5022 - accuracy: 0.8353 - val_loss: 1.5613 - val_accuracy: 0.5312
# Epoch 12/15
# 195/195 [==============================] - 13s 67ms/step - loss: 0.4058 - accuracy: 0.8747 - val_loss: 1.7070 - val_accuracy: 0.5202
# Epoch 13/15
# 195/195 [==============================] - 13s 67ms/step - loss: 0.3173 - accuracy: 0.9053 - val_loss: 1.7357 - val_accuracy: 0.5287
# Epoch 14/15
# 195/195 [==============================] - 13s 66ms/step - loss: 0.2474 - accuracy: 0.9298 - val_loss: 1.9180 - val_accuracy: 0.5219
# Epoch 15/15
# 195/195 [==============================] - 13s 67ms/step - loss: 0.1669 - accuracy: 0.9580 - val_loss: 2.0586 - val_accuracy: 0.5274

# %%
import matplotlib.pyplot as plt

plt.plot(histoty_34.history['loss'], 'r')
plt.plot(histoty_50.history['loss'], 'b')
plt.title('Model training loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['resnet32', 'resent50'], loc='upper left')
plt.show()

# %%
plt.plot(histoty_34.history['val_accuracy'], 'r')
plt.plot(histoty_50.history['val_accuracy'], 'b')
plt.title('Model validation accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['resnet32', 'resnet50'], loc='upper left')
plt.show()

# %% [markdown]
# # 회고
#
# > 1. 처음에는 모델을 구현한다는게 엄청 막연했지만.. 많은 참고자료들과 블로그를 보면서 만들어봤는데 해봤다는 것에 만족한다.
# 2. 직접만들어보니 모델의 프로세스들을 더 이해하기 좋은것 같다.
# 3. 너무 어렵다.. 점점 더 어려워진다..
